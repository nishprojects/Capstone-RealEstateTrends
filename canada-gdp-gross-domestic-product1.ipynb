# %%
import pandas as pd
import os
os.chdir('C:/Users/575774/MyProject/RealEstateMarketTrends/Source')

df=pd.read_excel('canada-gdp-gross-domestic-product.xlsx')

# %%
df.columns
# Out:
# Index(['Macrotrends Data Download', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'], dtype='object')

# %%
df.rename(columns={'Unnamed: 1': 'GDP ( Billions of US $)', 'Unnamed: 2': 'Per Capita (US $)', 'Unnamed: 3': 'Annual % Change'}, inplace=True)
df.columns
# Out:
# Index(['Macrotrends Data Download', 'GDP ( Billions of US $)',
#        'Per Capita (US $)', 'Annual % Change'],
#       dtype='object')

# %%
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4     False
#       ...
# 74    False
# 75    False
# 76    False
# 77    False
# 78     True
# Length: 79, dtype: bool

# %%
df.drop_duplicates(inplace = True)

# %%
df.head
# Out:
# <bound method NDFrame.head of                             Macrotrends Data Download GDP ( Billions of US $)  \
# 0                                                 NaN                     NaN
# 1                                Canada GDP 1960-2023                     NaN
# 4   DISCLAIMER AND TERMS OF USE: HISTORICAL DATA I...                     NaN
# 5   FOR INFORMATIONAL PURPOSES - NOT FOR TRADING P...                     NaN
# 6   NEITHER MACROTRENDS LLC NOR ANY OF OUR INFORMA...                     NaN
# ..                                                ...                     ...
# 73                                2017-12-31 00:00:00             1649.265644
# 74                                2018-12-31 00:00:00             1725.329193
# 75                                2019-12-31 00:00:00             1742.015045
# 76                                2020-12-31 00:00:00             1645.423408
# 77                                2021-12-31 00:00:00             1988.336332
#
# ...

# %%
df.dropna(inplace = True)
df
# Out:
#    Macrotrends Data Download   GDP ( Billions of US $)   Per Capita (US $)  \
# 15                      date   GDP ( Billions of US $)   Per Capita (US $)
# 17       1961-12-31 00:00:00                 40.934952            2240.433
# 18       1962-12-31 00:00:00                 42.227448           2268.5853
# 19       1963-12-31 00:00:00                 45.029989           2374.4984
# 20       1964-12-31 00:00:00                 49.377523           2555.1111
# 21       1965-12-31 00:00:00                  54.51518           2770.3618
# 22       1966-12-31 00:00:00                 61.088384           3047.1061
# 23       1967-12-31 00:00:00                 65.668655           3217.1593
# 24       1968-12-31 00:00:00                 71.829811           3462.6789
# 25       1969-12-31 00:00:00                 79.148412           3763.9534
# 54       1998-12-31 00:00:00                       634          21024.5851
# ...

# %%
df.rename(columns = {'Macrotrends Data Download':'Date', 'data1': 'GDP ( Billions of US $)', 'data2' : 'Per Capita (US $)','data3':'Annual % Change'}, inplace = True)
df
# Out:
#                    Date   GDP ( Billions of US $)   Per Capita (US $)  \
# 15                 date   GDP ( Billions of US $)   Per Capita (US $)
# 17  1961-12-31 00:00:00                 40.934952            2240.433
# 18  1962-12-31 00:00:00                 42.227448           2268.5853
# 19  1963-12-31 00:00:00                 45.029989           2374.4984
# 20  1964-12-31 00:00:00                 49.377523           2555.1111
# 21  1965-12-31 00:00:00                  54.51518           2770.3618
# 22  1966-12-31 00:00:00                 61.088384           3047.1061
# 23  1967-12-31 00:00:00                 65.668655           3217.1593
# 24  1968-12-31 00:00:00                 71.829811           3462.6789
# 25  1969-12-31 00:00:00                 79.148412           3763.9534
# 54  1998-12-31 00:00:00                       634          21024.5851
# 55  1999-12-31 00:00:00                678.412196          22315.2467
# ...

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#
# 9   2014-12-31 00:00:00              2228.620384        50955.9983
# 10  2015-12-31 00:00:00              1921.012051        43596.1355
# 11  2016-12-31 00:00:00              1885.820551        42315.6037
# 12  2017-12-31 00:00:00              2035.490673        45129.4293
# ...

# %%
df['Per Capita (US $)'] = df['Per Capita (US $)'].astype(float).mul(1.23418)
df
# Out:
#                    Date  GDP ( Billions of US $)  Per Capita (US $)  \
# 0   2005-12-31 00:00:00              1447.827171       44902.563600
# 1   2006-12-31 00:00:00              1628.210243       49989.301635
# 2   2007-12-31 00:00:00              1812.788771       55118.349335
# 3   2008-12-31 00:00:00              1916.668817       57649.171801
# 4   2009-12-31 00:00:00              1696.534858       50448.724523
# 5   2010-12-31 00:00:00              1996.092837       58700.172091
# 6   2011-12-31 00:00:00              2213.287860       64453.441253
# 7   2012-12-31 00:00:00              2256.533345       65003.137496
# 8   2013-12-31 00:00:00              2279.033606       64961.280282
# 9   2014-12-31 00:00:00              2228.620384       62888.873982
# 10  2015-12-31 00:00:00              1921.012051       53805.478511
# 11  2016-12-31 00:00:00              1885.820551       52225.071774
# 12  2017-12-31 00:00:00              2035.490673       55697.839053
# ...

# %%
df.rename(columns={'GDP ( Billions of US $)': 'GDP ( Billions in CAD $)', 'Per Capita (US $)': 'Per Capita (CAD $)'}, inplace=True)
df.columns
df
# Out:
#                    Date  GDP ( Billions in CAD $)  Per Capita (CAD $)  \
# 0   2005-12-31 00:00:00               1447.827171        44902.563600
# 1   2006-12-31 00:00:00               1628.210243        49989.301635
# 2   2007-12-31 00:00:00               1812.788771        55118.349335
# 3   2008-12-31 00:00:00               1916.668817        57649.171801
# 4   2009-12-31 00:00:00               1696.534858        50448.724523
# 5   2010-12-31 00:00:00               1996.092837        58700.172091
# 6   2011-12-31 00:00:00               2213.287860        64453.441253
# 7   2012-12-31 00:00:00               2256.533345        65003.137496
# 8   2013-12-31 00:00:00               2279.033606        64961.280282
# 9   2014-12-31 00:00:00               2228.620384        62888.873982
# 10  2015-12-31 00:00:00               1921.012051        53805.478511
# 11  2016-12-31 00:00:00               1885.820551        52225.071774
# ...

# %%
import matplotlib.pyplot as plt
x = df['Date']
y = df['GDP ( Billions in CAD $)']
plt.xlabel('Date')
plt.ylabel('GDP ( Billions in CAD $)')
plt.barh(x,y)
# Out:
# <BarContainer object of 17 artists>

# %%
import pyodbc

cnxn = pyodbc.connect(
    r'Driver=SQL Server;'
    r'Server=ADT230771;'
    r'Database=DWQueue;'
    r'Trusted_Connection=yes;'
    )
 
""" cnxn = pyodbc.connect(
    r'Driver=SQL Server;'
    r'Server=DESKTOP-BN48D65\SQLEXPRESS;'
    r'Database=Housing;'
    r'Trusted_Connection=yes;'
    ) """
cursor = cnxn.cursor()
sql = "INSERT INTO CanadaGDP (Date,GDP,PerCapita,Growth) VALUES (?,?,?,?)"
values = list(zip(list(df['Date']),list(df['GDP ( Billions in CAD $)']),list(df['Per Capita (CAD $)']),list(df['Annual % Change'])))
cursor.executemany(sql,values)
cursor.commit()
  

cursor.close()
