# %%
import pandas as pd
import os
os.chdir('C:/Users/829418/Documents/Capstone project')

df=pd.read_csv('canada-gdp-gross-domestic-product.csv')
df
# Out:
#                             Macrotrends Data Download   Unnamed: 1  \
# 0                                                 NaN          NaN
# 1                                Canada GDP 1960-2023          NaN
# 2                                                 NaN          NaN
# 3                                                 NaN          NaN
# 4   DISCLAIMER AND TERMS OF USE: HISTORICAL DATA I...          NaN
# ..                                                ...          ...
# 74                                         12/31/2018  1725.329193
# 75                                         12/31/2019  1742.015045
# 76                                         12/31/2020  1645.423408
# 77                                         12/31/2021  1988.336332
# 78                                         12/31/2021  1988.336332
#
#     Unnamed: 2 Unnamed: 3
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN        NaN
# 3          NaN        NaN
# ...

# %%
df.columns
# Out:
# Index(['Macrotrends Data Download', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'], dtype='object')

# %%
df.rename(columns={'Unnamed: 1': 'data1', 'Unnamed: 2': 'data2', 'Unnamed: 3': 'data3'}, inplace=True)
df.columns
# Out:
# Index(['Macrotrends Data Download', 'data1', 'data2', 'data3'], dtype='object')

# %%
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4     False
#       ...
# 74    False
# 75    False
# 76    False
# 77    False
# 78     True
# Length: 79, dtype: bool

# %%
df.drop_duplicates(inplace = True)

# %%
df.head
# Out:
# <bound method NDFrame.head of                             Macrotrends Data Download        data1  \
# 0                                                 NaN          NaN
# 1                                Canada GDP 1960-2023          NaN
# 4   DISCLAIMER AND TERMS OF USE: HISTORICAL DATA I...          NaN
# 5   FOR INFORMATIONAL PURPOSES - NOT FOR TRADING P...          NaN
# 6   NEITHER MACROTRENDS LLC NOR ANY OF OUR INFORMA...          NaN
# ..                                                ...          ...
# 73                                         12/31/2017  1649.265644
# 74                                         12/31/2018  1725.329193
# 75                                         12/31/2019  1742.015045
# 76                                         12/31/2020  1645.423408
# 77                                         12/31/2021  1988.336332
#
#          data2   data3
# 0          NaN     NaN
# 1          NaN     NaN
# 4          NaN     NaN
# 5          NaN     NaN
# ...

# %%
df.dropna(inplace = True)

# %%
df.dropna(inplace = True)
df
# Out:
#    Macrotrends Data Download                     data1               data2  \
# 15                      date   GDP ( Billions of US $)   Per Capita (US $)
# 17                12/31/1961               40.93495206            2240.433
# 18                12/31/1962               42.22744763           2268.5853
# 19                12/31/1963               45.02998856           2374.4984
# 20                12/31/1964                49.3775229           2555.1111
# 21                12/31/1965               54.51517958           2770.3618
# 22                12/31/1966               61.08838404           3047.1061
# 23                12/31/1967                65.6686555           3217.1593
# 24                12/31/1968               71.82981052           3462.6789
# 25                12/31/1969               79.14841166           3763.9534
# 54                12/31/1998                       634          21024.5851
# ...

# %%
df = df.reset_index(drop =True)
print(df.head())
# Out:
#   Macrotrends Data Download                     data1               data2  \
# 0                      date   GDP ( Billions of US $)   Per Capita (US $)
# 1                12/31/1961               40.93495206            2240.433
# 2                12/31/1962               42.22744763           2268.5853
# 3                12/31/1963               45.02998856           2374.4984
# 4                12/31/1964                49.3775229           2555.1111
#
#               data3
# 0   Annual % Change
# 1            3.1633
# 2            7.4254
# 3            5.3495
# 4            6.6429
